# %% [markdown]
# # Example: Setup of a Project

# %% [markdown]
# ## Example of a Good Setup

# %% [markdown]
# Imports and magic

# %%
# I import libraries
import numpy as np
import matplotlib.pyplot as plt

# I import my module
import Example_Module as ex_m

# I predefine options for all plots
plt.rcParams.update({"axes.grid":True,"grid.color":"black","grid.alpha":"0.25","grid.linestyle":"-"})
plt.rcParams.update({'figure.figsize': (10, 6)})
plt.rcParams.update({'font.size': 10})

# %% [markdown]
# I define x-values and find y-values

# %%
# Define x-values
x_vals = np.linspace(-5,5,100)

# Find y-values
y_vals = ex_m.x_squared(x=x_vals)

# %% [markdown]
# I create a graph of x squared

# %%
# I call the function simple_fig with x_vals and y_vals as input
# I also set the color, label, and legend position
ex_m.simple_fig(x=x_vals, y=y_vals, color='blue', label='$y=x^2$', legend_pos='lower right')

# %% [markdown]
# ## Example of a Bad Setup

# %% [markdown]
# Graph

# %%
import numpy as np

# x and y values
x_vals = np.linspace(-5,5,100)

def x_squared(x):
    return x**2

y_vals = x_squared(x_vals)

# %%
import matplotlib.pyplot as plt

# Figure
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(x_vals, y_vals)
