# %% [markdown]
# # Example: Setup of a Project

# %% [markdown]
# ## Good Example

# %% [markdown]
# Imports and magic

# %%
import numpy as np
import matplotlib.pyplot as plt

import Example as ex

# %% [markdown]
# I define x-values and find y-values

# %%
# Define x-values
x_vals = np.linspace(-5,5,100)

# Find y-values
y_vals = ex.x_squared(x_vals)

# %% [markdown]
# I create a graph of x squared

# %%
# I call the function simple_fig with x_vals and y_vals as input
ex.simple_fig(x_vals, y_vals, color='blue', label='$y = x^2$')

# %% [markdown]
# ## Bad Example

# %%
import numpy as np

# x and y values
x_vals = np.linspace(-5,5,100)

def x_squared(x):
    return x**2

y_vals = x_squared(x_vals)

# %%
import matplotlib.pyplot as plt

# Figure
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(x_vals, y_vals)
