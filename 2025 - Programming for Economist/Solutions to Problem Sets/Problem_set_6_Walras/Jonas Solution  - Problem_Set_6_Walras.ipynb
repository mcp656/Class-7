# %% [markdown]
# # Problem set 6: Walras-equilibrium models

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - 1. [Simple supply and demand](#toc1_)
# - 2. [Exchange economy with quasi-linear preferences](#toc2_)
#   - 2.1. [Improvement set](#toc2_1_)
#   - 2.2. [Equilibrium](#toc2_2_)
#   - 2.3. [Dictators](#toc2_3_)
# - 3. [Production Economy with CO2 tax](#toc3_)
#   - 3.1. [Labor supply](#toc3_1_)
#   - 3.2. [Grid search](#toc3_2_)
#   - 3.3. [Equilibrium prices](#toc3_3_)
#   - 3.4. [Optimal CO2 tax](#toc3_4_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=true
# 	anchor=true
# 	flat=false
# 	minLevel=2
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({'axes.grid':True,'grid.color':'black','grid.alpha':'0.25','grid.linestyle':'--'})
plt.rcParams.update({'font.size': 14})
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
from scipy import optimize

# %% [markdown]
# ## 1. <a id='toc1_'></a>[Simple supply and demand](#toc0_)

# %% [markdown]
# In a simple market model, the **demand function** gives the quantity of a good that consumers are willing to buy
# at each price, while the **supply function** gives the quantity that producers are willing to sell.
#
# An **equilibrium** occurs when the quantity demanded equals the quantity supplied:
#
# $$
# D(p^*) = S(p^*)
# $$
#
# or equivalently when **excess demand** $ Z(p) = D(p) - S(p) $ equals zero.
#
# The equilibrium price $ p^* $ is found by solving:
#
# $$
# Z(p) = 0
# $$
#
# Once $ p^* $ is found, the corresponding equilibrium quantity is $ q^* = D(p^*) = S(p^*) $.

# %% [markdown]
# Here are the demand, supply and excess demand functions:

# %%
def demand(p, a=10, b=1):
    """Demand: D(p) = a - b*p"""
    return a - b * p

def supply(p, c=2, d=1):
    """Supply: S(p) = c + d*p"""
    return c + d * p

def excess_demand(p,do_print=False):
    """Excess demand function"""

    Z = demand(p) - supply(p)
    if do_print: print(f'p = {p:12.8f}, {Z = :12.8f}')

    return Z

# %% [markdown]
# **Question a:** Find the equilibrium price with a root-finder.

# %%
obj = lambda p: excess_demand(p,do_print=True)
res = optimize.root_scalar(obj, bracket=[0, 10.0], method='bisect')

p_star = res.root
q_star = demand(p_star)

print(f'Equilibrium price: p* = {p_star:.2f}')
print(f'Equilibrium quantity: q* = {q_star:.2f}')
# Out:
# p =   0.00000000, Z =   8.00000000
# p =  10.00000000, Z = -12.00000000
# p =   5.00000000, Z =  -2.00000000
# p =   2.50000000, Z =   3.00000000
# p =   3.75000000, Z =   0.50000000
# p =   4.37500000, Z =  -0.75000000
# p =   4.06250000, Z =  -0.12500000
# p =   3.90625000, Z =   0.18750000
# p =   3.98437500, Z =   0.03125000
# p =   4.02343750, Z =  -0.04687500
# p =   4.00390625, Z =  -0.00781250
# p =   3.99414062, Z =   0.01171875
# p =   3.99902344, Z =   0.00195312
# p =   4.00146484, Z =  -0.00292969
# p =   4.00024414, Z =  -0.00048828
# p =   3.99963379, Z =   0.00073242
# p =   3.99993896, Z =   0.00012207
# p =   4.00009155, Z =  -0.00018311
# p =   4.00001526, Z =  -0.00003052
# p =   3.99997711, Z =   0.00004578
# p =   3.99999619, Z =   0.00000763
# p =   4.00000572, Z =  -0.00001144
# p =   4.00000095, Z =  -0.00000191
# p =   3.99999857, Z =   0.00000286
# p =   3.99999976, Z =   0.00000048
# p =   4.00000036, Z =  -0.00000072
# p =   4.00000006, Z =  -0.00000012
# p =   3.99999991, Z =   0.00000018
# p =   3.99999999, Z =   0.00000003
# p =   4.00000002, Z =  -0.00000004
# p =   4.00000000, Z =  -0.00000001
# p =   3.99999999, Z =   0.00000001
# p =   4.00000000, Z =   0.00000000
# p =   4.00000000, Z =  -0.00000000
# p =   4.00000000, Z =  -0.00000000
# p =   4.00000000, Z =   0.00000000
# p =   4.00000000, Z =   0.00000000
# p =   4.00000000, Z =  -0.00000000
# p =   4.00000000, Z =  -0.00000000
# p =   4.00000000, Z =   0.00000000
# p =   4.00000000, Z =   0.00000000
# p =   4.00000000, Z =  -0.00000000
# p =   4.00000000, Z =  -0.00000000
# p =   4.00000000, Z =   0.00000000
# p =   4.00000000, Z =   0.00000000
# Equilibrium price: p* = 4.00
# Equilibrium quantity: q* = 6.00

# %% [markdown]
# **Question b:** Find the equilibrium price applying the following auction-like algorithm (also called tâtonnement).

# %% [markdown]
# 1. Guess on $p = 5.0$ and set $i=0$
# 1. Calculate $Z(p)$.
# 1. Stop if $Z(p) < \text{tol.}$.
# 1. Else set $p = p + \nu Z(p)$ and go to step 2 if $i+1 < \text{maxiter}$.

# %%
nu = 0.1
p = 5.0
tol = 1e-8
maxiter = 100
for i in range(maxiter):
    Z = excess_demand(p)
    # ADD CODE HERE
    print(f'Iteration {i+1:3d}: p = {p:12.8f}, Z = {Z:12.8f}')

if abs(Z) < tol:
    print(f'Tâtonnement converged in {i+1} iterations to price p = {p:.8f}')
else:
    print(f'Tâtonnement did not converge in {maxiter} iterations.')
# Out:
# Iteration   1: p =   5.00000000, Z =  -2.00000000
# Iteration   2: p =   5.00000000, Z =  -2.00000000
# Iteration   3: p =   5.00000000, Z =  -2.00000000
# Iteration   4: p =   5.00000000, Z =  -2.00000000
# Iteration   5: p =   5.00000000, Z =  -2.00000000
# Iteration   6: p =   5.00000000, Z =  -2.00000000
# Iteration   7: p =   5.00000000, Z =  -2.00000000
# Iteration   8: p =   5.00000000, Z =  -2.00000000
# Iteration   9: p =   5.00000000, Z =  -2.00000000
# Iteration  10: p =   5.00000000, Z =  -2.00000000
# Iteration  11: p =   5.00000000, Z =  -2.00000000
# Iteration  12: p =   5.00000000, Z =  -2.00000000
# Iteration  13: p =   5.00000000, Z =  -2.00000000
# Iteration  14: p =   5.00000000, Z =  -2.00000000
# Iteration  15: p =   5.00000000, Z =  -2.00000000
# Iteration  16: p =   5.00000000, Z =  -2.00000000
# Iteration  17: p =   5.00000000, Z =  -2.00000000
# Iteration  18: p =   5.00000000, Z =  -2.00000000
# Iteration  19: p =   5.00000000, Z =  -2.00000000
# Iteration  20: p =   5.00000000, Z =  -2.00000000
# Iteration  21: p =   5.00000000, Z =  -2.00000000
# Iteration  22: p =   5.00000000, Z =  -2.00000000
# Iteration  23: p =   5.00000000, Z =  -2.00000000
# Iteration  24: p =   5.00000000, Z =  -2.00000000
# Iteration  25: p =   5.00000000, Z =  -2.00000000
# Iteration  26: p =   5.00000000, Z =  -2.00000000
# Iteration  27: p =   5.00000000, Z =  -2.00000000
# Iteration  28: p =   5.00000000, Z =  -2.00000000
# Iteration  29: p =   5.00000000, Z =  -2.00000000
# Iteration  30: p =   5.00000000, Z =  -2.00000000
# Iteration  31: p =   5.00000000, Z =  -2.00000000
# Iteration  32: p =   5.00000000, Z =  -2.00000000
# Iteration  33: p =   5.00000000, Z =  -2.00000000
# Iteration  34: p =   5.00000000, Z =  -2.00000000
# Iteration  35: p =   5.00000000, Z =  -2.00000000
# Iteration  36: p =   5.00000000, Z =  -2.00000000
# Iteration  37: p =   5.00000000, Z =  -2.00000000
# Iteration  38: p =   5.00000000, Z =  -2.00000000
# Iteration  39: p =   5.00000000, Z =  -2.00000000
# Iteration  40: p =   5.00000000, Z =  -2.00000000
# Iteration  41: p =   5.00000000, Z =  -2.00000000
# Iteration  42: p =   5.00000000, Z =  -2.00000000
# Iteration  43: p =   5.00000000, Z =  -2.00000000
# Iteration  44: p =   5.00000000, Z =  -2.00000000
# Iteration  45: p =   5.00000000, Z =  -2.00000000
# Iteration  46: p =   5.00000000, Z =  -2.00000000
# Iteration  47: p =   5.00000000, Z =  -2.00000000
# Iteration  48: p =   5.00000000, Z =  -2.00000000
# Iteration  49: p =   5.00000000, Z =  -2.00000000
# Iteration  50: p =   5.00000000, Z =  -2.00000000
# Iteration  51: p =   5.00000000, Z =  -2.00000000
# Iteration  52: p =   5.00000000, Z =  -2.00000000
# Iteration  53: p =   5.00000000, Z =  -2.00000000
# Iteration  54: p =   5.00000000, Z =  -2.00000000
# Iteration  55: p =   5.00000000, Z =  -2.00000000
# Iteration  56: p =   5.00000000, Z =  -2.00000000
# Iteration  57: p =   5.00000000, Z =  -2.00000000
# Iteration  58: p =   5.00000000, Z =  -2.00000000
# Iteration  59: p =   5.00000000, Z =  -2.00000000
# Iteration  60: p =   5.00000000, Z =  -2.00000000
# Iteration  61: p =   5.00000000, Z =  -2.00000000
# Iteration  62: p =   5.00000000, Z =  -2.00000000
# Iteration  63: p =   5.00000000, Z =  -2.00000000
# Iteration  64: p =   5.00000000, Z =  -2.00000000
# Iteration  65: p =   5.00000000, Z =  -2.00000000
# Iteration  66: p =   5.00000000, Z =  -2.00000000
# Iteration  67: p =   5.00000000, Z =  -2.00000000
# Iteration  68: p =   5.00000000, Z =  -2.00000000
# Iteration  69: p =   5.00000000, Z =  -2.00000000
# Iteration  70: p =   5.00000000, Z =  -2.00000000
# Iteration  71: p =   5.00000000, Z =  -2.00000000
# Iteration  72: p =   5.00000000, Z =  -2.00000000
# Iteration  73: p =   5.00000000, Z =  -2.00000000
# Iteration  74: p =   5.00000000, Z =  -2.00000000
# Iteration  75: p =   5.00000000, Z =  -2.00000000
# Iteration  76: p =   5.00000000, Z =  -2.00000000
# Iteration  77: p =   5.00000000, Z =  -2.00000000
# Iteration  78: p =   5.00000000, Z =  -2.00000000
# Iteration  79: p =   5.00000000, Z =  -2.00000000
# Iteration  80: p =   5.00000000, Z =  -2.00000000
# Iteration  81: p =   5.00000000, Z =  -2.00000000
# Iteration  82: p =   5.00000000, Z =  -2.00000000
# Iteration  83: p =   5.00000000, Z =  -2.00000000
# Iteration  84: p =   5.00000000, Z =  -2.00000000
# Iteration  85: p =   5.00000000, Z =  -2.00000000
# Iteration  86: p =   5.00000000, Z =  -2.00000000
# Iteration  87: p =   5.00000000, Z =  -2.00000000
# Iteration  88: p =   5.00000000, Z =  -2.00000000
# Iteration  89: p =   5.00000000, Z =  -2.00000000
# Iteration  90: p =   5.00000000, Z =  -2.00000000
# Iteration  91: p =   5.00000000, Z =  -2.00000000
# Iteration  92: p =   5.00000000, Z =  -2.00000000
# Iteration  93: p =   5.00000000, Z =  -2.00000000
# Iteration  94: p =   5.00000000, Z =  -2.00000000
# Iteration  95: p =   5.00000000, Z =  -2.00000000
# Iteration  96: p =   5.00000000, Z =  -2.00000000
# Iteration  97: p =   5.00000000, Z =  -2.00000000
# Iteration  98: p =   5.00000000, Z =  -2.00000000
# Iteration  99: p =   5.00000000, Z =  -2.00000000
# Iteration 100: p =   5.00000000, Z =  -2.00000000
# Tâtonnement did not converge in 100 iterations.

# %% [markdown]
# ## 2. <a id='toc2_'></a>[Exchange economy with quasi-linear preferences](#toc0_)

# %% [markdown]
# We consider an **exchange economy** like the one in the lecture, but with **quasi-linear preferencer**.

# %% [markdown]
# The general setup is:
#
# - Two consumers, A and B.
# - Two goods, $x_{1}$ and $x_{2}$.

# %% [markdown]
# **Endowments:**
#
# * The initial endowments are $\omega_{1}^{A}\geq0$ and $\omega_{2}^{A}\geq0$.
# * The total endowment of each good is always one, such that $\omega_{1}^{B} = 1-\omega_{1}^{A}$ and $\omega_{2}^{B} = 1-\omega_{2}^{A}$.
# * We define the vectors $\boldsymbol{\omega}^{A}$ = $(\omega_{1}^{A},\omega_{2}^{A})$, and $\boldsymbol{\omega}^{B}=(\omega_{1}^{B},\omega_{2}^{B})$.

# %% [markdown]
# **Prices:** $\boldsymbol{p}=(p_{1},p_{2})$ with numeraire $p_2 = 1$.

# %% [markdown]
# **Utility functions**:
#
# $$
# \begin{aligned}
# u^{A}(x_{1},x_{2})	&= \log(x_{1}) + {\alpha} x_{2},\,\,\,\alpha>0 \\
# u^{B}(x_{1},x_{2})	&= \log(x_{1}) + {\beta} x_{2},\,\,\,\beta>0 \\
# \end{aligned}
# $$

# %% [markdown]
# **Demand functions:** We define the vectors $\boldsymbol{x}^{A} = (x_{1}^{A},x_{2}^{A})$, and $\boldsymbol{x}^{B}=(x_{1}^{B},x_{2}^{B})$.
#
# $$
# \begin{aligned}
# x^{A\star}(\boldsymbol{p},\boldsymbol{\omega}^A) & =
# \begin{cases}
# \left(\dfrac{1}{\alpha p_{1}},\, m^A - \dfrac{1}{\alpha}\right)
# & \text{if } m^A > \dfrac{1}{\alpha} \\
# \left(\dfrac{m^A}{p_{1}},\, 0\right)
# & \text{if } m^A \le \dfrac{1}{\alpha}
# \end{cases} \\
# m^A &= p_1 \omega_1^A + \omega_2^A
# \end{aligned}
# $$
#
# $$
# \begin{aligned}
# x^{B\star}(\boldsymbol{p},\boldsymbol{\omega}^B) & =
# \begin{cases}
# \left(\dfrac{1}{\beta p_{1}},\, m^B - \dfrac{1}{\beta}\right)
# & \text{if } m^B > \dfrac{1}{\beta} \\
# \left(\dfrac{m^B}{p_{1}},\, 0\right)
# & \text{if } m^B \le \dfrac{1}{\beta}
# \end{cases} \\
# m^B &= p_1 (1-\omega_1^A) + (1 - \omega_2^A)
# \end{aligned}
# $$

# %% [markdown]
# **Walras equilibrium**: Market clearing requires demand = endowment (supply),
#
# $$
# \begin{aligned}
# x_{1}^{A\star}(\boldsymbol{p},\boldsymbol{\omega}^{A})+x_{1}^{B\star}(\boldsymbol{p},\boldsymbol{\omega}^{B}) &= \omega_{1}^{A}+\omega_{1}^{B} \\
# x_{2}^{A\star}(\boldsymbol{p},\boldsymbol{\omega}^{A})+x_{2}^{B\star}(\boldsymbol{p},\boldsymbol{\omega}^{B}) &= \omega_{2}^{A}+\omega_{2}^{B}
# \end{aligned}
# $$

# %% [markdown]
# The class `ExchangeEconomyModelQuasiLinearClass` in `ExchangeEconomyModelQuasiLinear.py` is the starting point for solving this model:

# %% [markdown]
# 1. It inherites the basic functationality from `ExchangeEconomyModelClass` in `ExchangeEconomyModel.py`.
# 2. You will be updating the currently not implemented methods.

# %%
from ExchangeEconomyQuasiLinearModel import ExchangeEconomyModelQuasiLinearClass

# %% [markdown]
# **Note:** The solution model class is in `A2_ExchangeEconomyQuasiLinearModel.py`.

# %% [markdown]
# ### 2.1. <a id='toc2_1_'></a>[Improvement set](#toc0_)

# %% [markdown]
# Update the `.x2A_indifference` and `.x2B_indifference` methods.
#
# Create a figure with:
#
# 1. The endowment
# 1. The improvement set
# 1. The indifferences curves through the endowment
# 1. Indifferences curves just below and above the endowment
#
# Remember to use the plotting functionalities in the class.

# %%
model = ExchangeEconomyModelQuasiLinearClass()

par = model.par
sol = model.sol
sim = model.sim

fig,ax_A,ax_B = model.create_edgeworthbox()

ax_A.scatter(par.w1A,par.w2A,marker='s',color='black',label='endowment',zorder=3)

# Plot indifference curves
model.indifference_curve_A(ax_A,par.w1A,par.w2A,color=colors[0],label='A')
    
model.indifference_curve_B(ax_B,1-par.w1A,1-par.w2A,color=colors[1],label='B')

# Plot improvement set - makes both better off
model.plot_improvement_set(ax_A)

model.add_legend(ax_A,ax_B)

# %% [markdown]
# ### 2.2. <a id='toc2_2_'></a>[Equilibrium](#toc0_)

# %% [markdown]
# **Task:** Update the `.demand_A` and `.demand_B` methods.

# %% [markdown]
# **Question A:** Solve for the Walras-equilibrium.

# %%
# Only works if model = ExchangeEconomyModelQuasiLinearClass() is "clean"
model = ExchangeEconomyModelQuasiLinearClass()
model.solve_walras(p_guess=1.0,print_output=True)
# Out:
#   0: p1 =   1.00000000 -> excess demand of good 1 ->     0.90000000, x1A =   1.00000000, x2A =   0.10000000, x1B =   0.90000000, x2B =   0.00000000
#   1: p1 =   1.45000000 -> excess demand of good 1 ->     0.37241379, x1A =   0.68965517, x2A =   0.46000000, x1B =   0.68275862, x2B =   0.00000000
#   2: p1 =   1.63620690 -> excess demand of good 1 ->     0.22233930, x1A =   0.61116965, x2A =   0.60896552, x1B =   0.61116965, x2B =   0.02724138
#   3: p1 =   1.74737655 -> excess demand of good 1 ->     0.14457299, x1A =   0.57228649, x2A =   0.69790124, x1B =   0.57228649, x2B =   0.04947531
#   4: p1 =   1.81966304 -> excess demand of good 1 ->     0.09910459, x1A =   0.54955229, x2A =   0.75573043, x1B =   0.54955229, x2B =   0.06393261
#   5: p1 =   1.86921534 -> excess demand of good 1 ->     0.06996768, x1A =   0.53498384, x2A =   0.79537227, x1B =   0.53498384, x2B =   0.07384307
#  10: p1 =   1.97101674 -> excess demand of good 1 ->     0.01470472, x1A =   0.50735236, x2A =   0.87681339, x1B =   0.50735236, x2B =   0.09420335
#  15: p1 =   1.99322338 -> excess demand of good 1 ->     0.00339983, x1A =   0.50169991, x2A =   0.89457871, x1B =   0.50169991, x2B =   0.09864468
#  20: p1 =   1.99839742 -> excess demand of good 1 ->     0.00080193, x1A =   0.50040097, x2A =   0.89871793, x1B =   0.50040097, x2B =   0.09967948
#  25: p1 =   1.99962001 -> excess demand of good 1 ->     0.00019003, x1A =   0.50009502, x2A =   0.89969601, x1B =   0.50009502, x2B =   0.09992400
#  30: p1 =   1.99990984 -> excess demand of good 1 ->     0.00004508, x1A =   0.50002254, x2A =   0.89992788, x1B =   0.50002254, x2B =   0.09998197
#  35: p1 =   1.99997861 -> excess demand of good 1 ->     0.00001070, x1A =   0.50000535, x2A =   0.89998289, x1B =   0.50000535, x2B =   0.09999572
#  40: p1 =   1.99999492 -> excess demand of good 1 ->     0.00000254, x1A =   0.50000127, x2A =   0.89999594, x1B =   0.50000127, x2B =   0.09999898
#  45: p1 =   1.99999880 -> excess demand of good 1 ->     0.00000060, x1A =   0.50000030, x2A =   0.89999904, x1B =   0.50000030, x2B =   0.09999976
#  50: p1 =   1.99999971 -> excess demand of good 1 ->     0.00000014, x1A =   0.50000007, x2A =   0.89999977, x1B =   0.50000007, x2B =   0.09999994
#  55: p1 =   1.99999993 -> excess demand of good 1 ->     0.00000003, x1A =   0.50000002, x2A =   0.89999995, x1B =   0.50000002, x2B =   0.09999999
#
# Solved!
#   60: p1 =   1.99999998, x1A =   0.50000000, x2A =   0.89999999
#  Excess demand of good 1:     0.00000001
#  Excess demand of good 2:    -0.00000002

# %% [markdown]
# **Question B:** Show how the equilibrium price and allocation varies with $\alpha \in [0.5,3.0]$.

# %%
for alpha in np.linspace(0.5,3.0,20):
    model_ = ExchangeEconomyModelQuasiLinearClass()
    model_.par.alpha = alpha
    model_.solve_walras(p_guess=1.0,print_output=True)
# Out:
#   0: p1 =   1.00000000 -> excess demand of good 1 ->     1.00000000, x1A =   1.10000000, x2A =   0.00000000, x1B =   0.90000000, x2B =   0.00000000
#   1: p1 =   1
#  65: p1 =   2.58333266 -> excess demand of good 1 ->     0.00000026, x1A =   0.61290339, x2A =   0.78333279, x1B =   0.38709688, x2B =   0.21666653
#  70: p1 =   2.58333310 -> excess demand of good 1 ->     0.00000009, x1A =   0.61290328, x2A =   0.78333315, x1B =   0.38709681, x2B =   0.21666662
#  75: p1 =   2.58333325 -> excess demand of good 1 ->     0.00000003, x1A =   0.61290324, x2A =   0.78333327, x1B =   0.38709679, x2B =   0.21666665
#  80: p1 =   2.58333331 -> excess demand of good 1 ->     0.00000001, x1A =   0.61290323, x2A =   0.78333331, x1B =   0.38709678, x2B =   0.21666666
#
# Solved!
#   81: p1 =   2.58333331, x1A =   0.61290323, x2A =   0.78333332
#  Excess demand of good 1:     0.00000001
#  Excess demand of good 2:    -0.00000002
#   0: p1 =   1.00000000 -> excess demand of good 1 ->     1.00000000, x1A =   1.10000000, x2A =   0.00000000, x1B =   0.90000000, x2B =   0.00000000
#   1: p1 =   1.50000000 -> excess demand of good 1 ->     0.54022989, x1A =   0.87356322, x2A =   0.18965517, x1B =   0.66666667, x2B =   0.00000000
#   2: p1 =   1.77011494 -> excess demand of good 1 ->     0.30519481, x1A =   0.74025974, x2A =   0.40574713, x1B =   0.56493506, x2B =   0.05402299
#   3: p1 =   1.92271235 -> excess demand of good 1 ->     0.20160711, x1A =   0.68150851, x2A =   0.52782505, x1B =   0.52009860, x2B =   0.08454247
#   4: p1 =   2.02351590 -> excess demand of good 1 ->     0.14174780, x1A =   0.64755845, x2A =   0.60846789, x1B =   0.49418935, x2B =   0.10470318
#   5: p1 =   2.09438980 -> excess demand of good 1 ->     0.10311119, x1A =   0.62564515, x2A =   0.66516701, x1B =   0.47746604, x2B =   0.11887796
#  10: p1 =   2.25191827 -> excess demand of good 1 ->     0.02594524, x1A =   0.58187939, x2A =   0.79118979, x1B =   0.44406585, x2B =   0.15038365
#  15: p1 =   2.29347786 -> excess demand of good 1 ->     0.00735432, x1A =   0.57133529, x2A =   0.82443746, x1B =   0.43601903, x2B =   0.15869557
#  20: p1 =   2.30539490 -> excess demand of good 1 ->     0.00214710, x1A =   0.56838194, x2A =   0.83397110, x1B =   0.43376516, x2B =   0.16107898
#  25: p1 =   2.30888540 -> excess demand of good 1 ->     0.00063209, x1A =   0.56752268, x2A =   0.83676349, x1B =   0.43310941, x2B =   0.16177708
#  30: p1 =   2.30991394 -> excess demand of good 1 ->     0.00018654, x1A =   0.56726998, x2A =   0.83758633, x1B =   0.43291656, x2B =   0.16198279
#  35: p1 =   2.31021756 -> excess demand of good 1 ->     0.00005509, x1A =   0.56719542, x2A =   0.83782922, x1B =   0.43285966, x2B =   0.16204351
#  40: p1 =   2.31030723 -> excess demand of good 1 ->     0.00001627, x1A =   0.56717341, x2A =   0.83790096, x1B =   0.43284286, x2B =   0.16206145
#  45: p1 =   2.31033372 -> excess demand of good 1 ->     0.00000481, x1A =   0.56716691, x2A =   0.83792215, x1B =   0.43283790, x2B =   0.16206674
#  50: p1 =   2.31034155 -> excess demand of good 1 ->     0.00000142, x1A =   0.56716498, x2A =   0.83792841, x1B =   0.43283644, x2B =   0.16206831
#  55: p1 =   2.11764686 -> excess demand of good 1 ->     0.00000009, x1A =   0.52777783, x2A =   0.87647043, x1B =   0.47222227, x2B =   0.12352937
#  60: p1 =   2.11764701 -> excess demand of good 1 ->     0.00000002, x1A =   0.52777779, x2A =   0.87647055, x1B =   0.47222223, x2B =   0.12352940
#
# Solved!
#   64: p1 =   2.11764704, x1A =   0.52777778, x2A =   0.87647057
#  Excess demand of good 1:     0.00000001
#  Excess demand of good 2:    -0.00000002
#   0: p1 =   1.00000000 -> excess demand of good 1 ->     0.87435897, x1A =   0.97435897, x2A =   0.12564103, x1B =   0.90000000, x2B =   0.00000000
#   1: p1 =   1.43717949 -> excess demand of good 1 ->     0.36503122, x1A =   0.67796610, x2A =   0.47538462, x1B =   0.68706512, x2B =   0.00000000
#   2: p1 =   1.61969510 -> excess demand of good 1 ->     0.21896953, x1A =   0.60156938, x2A =   0.62139710, x1B =   0.61740015, x2B =   0.02393902
#   3: p1 =   1.72917986 -> excess demand of good 1 ->     0.14178925, x1A =   0.56348041, x2A =   0.70898492, x1B =   0.57830884, x2B =   0.04583597
#   4: p1 =   1.80007449 -> excess demand of good 1 ->     0.09682071, x1A =   0.54128814, x2A =   0.76570062, x1B =   0.55553257, x2B =   0.06001490
#   5: p1 =   1.84848484 -> excess demand of good 1 ->     0.06809584, x1A =   0.52711223, x2A =   0.80442890, x1B =   0.54098361, x2B =   0.06969697
#  10: p1 =   1.94703412 -> excess demand of good 1 ->     0.01403409, x1A =   0.50043241, x2A =   0.88326832, x1B =   0.51360168, x2B =   0.08940682
#  15: p1 =   1.96810398 -> excess demand of good 1 ->     0.00317818, x1A =   0.49507495, x2A =   0.90012421, x1B =   0.50810323, x2B =   0.09362080
#  20: p1 =   1.97291122 -> excess demand of good 1 ->     0.00073382, x1A =   0.49386864, x2A =   0.90397000, x1B =   0.50686518, x2B =   0.09458224
#  25: p1 =   1.97402304 -> excess demand of good 1 ->     0.00017018, x1A =   0.49359048, x2A =   0.90485946, x1B =   0.50657970, x2B =   0.09480461
#  30: p1 =   1.97428098 -> excess demand of good 1 ->     0.00003951, x1A =   0.49352599, x2A =   0.90506581, x1B =   0.50651352, x2B =   0.09485620
#  35: p1 =   1.97434086 -> excess demand of good 1 ->     0.00000917, x1A =   0.49351102, x2A =   0.90511372, x1B =   0.50649815, x2B =   0.09486817
#  40: p1 =   1.97435477 -> excess demand of good 1 ->     0.00000213, x1A =   0.49350754, x2A =   0.90512484, x1B =   0.50649459, x2B =   0.09487095
#  45: p1 =   1.97435800 -> excess demand of good 1 ->     0.00000049, x1A =   0.49350674, x2A =   0.90512742, x1B =   0.50649376, x2B =   0.09487160
#  50: p1 =   1.97435875 -> excess demand of good 1 ->     0.00000011, x1A =   0.49350655, x2A =   0.90512802, x1B =   0.50649356, x2B =   0.09487175
#  55: p1 =   1.97435892 -> excess demand of good 1 ->     0.00000003, x1A =   0.49350651, x2A =   0.90512816, x1B =   0.50649352, x2B =   0.09487178
#
# Solved!
#   59: p1 =   1.97435896, x1A =   0.49350650, x2A =   0.90512819
#  Excess demand of good 1:     0.00000001
#  Excess demand of good 2:    -0.00000002
#   0: p1 =   1.00000000 -> excess demand of good 1 ->
#  20: p1 =   1.70329096 -> excess demand of good 1 ->     0.00024232, x1A =   0.41314357, x2A =   0.95892906, x1B =   0.58709876, x2B =   0.04065819
#  25: p1 =   1.70363106 -> excess demand of good 1 ->     0.00004264, x1A =   0.41306109, x2A =   0.95920115, x1B =   0.58698155, x2B =   0.04072621
#  30: p1 =   1.70369092 -> excess demand of good 1 ->     0.00000751, x1A =   0.41304658, x2A =   0.95924903, x1B =   0.58696093, x2B =   0.04073818
#  35: p1 =   1.70370145 -> excess demand of good 1 ->     0.00000132, x1A =   0.41304402, x2A =   0.95925746, x1B =   0.58695730, x2B =   0.04074029
#  40: p1 =   1.70370331 -> excess demand of good 1 ->     0.00000023, x1A =   0.41304357, x2A =   0.95925894, x1B =   0.58695666, x2B =   0.04074066
#  45: p1 =   1.70370363 -> excess demand of good 1 ->     0.00000004, x1A =   0.41304350, x2A =   0.95925920, x1B =   0.58695655, x2B =   0.04074073
#
# Solved!
#   50: p1 =   1.70370369, x1A =   0.41304348, x2A =   0.95925925
#  Excess demand of good 1:     0.00000001
#  Excess demand of good 2:    -0.00000001
#   0: p1 =   1.00000000 -> excess demand of good 1 ->     0.54406780, x1A =   0.64406780, x2A =   0.45593220, x1B =   0.90000000, x2B =   0.00000000
#   1: p1 =   1.27203390 -> excess demand of good 1 ->     0.25662891, x1A =   0.50632911, x2A =   0.67355932, x1B =   0.75029980, x2B =   0.00000000
#   2: p1 =   1.40034836 -> excess demand of good 1 ->     0.15980960, x1A =   0.45993398, x2A =   0.77621089, x1B =   0.69987562, x2B =   0.00000000
#   3: p1 =   1.48025316 -> excess demand of good 1 ->     0.10799860, x1A =   0.43510652, x2A =   0.84013473, x1B =   0.67289208, x2B =   0.00000000
#   4: p1 =   1.53425246 -> excess demand of good 1 ->     0.07157580, x1A =   0.41979258, x2A =   0.88333417, x1B =   0.65178322, x2B =   0.00685049
#   5: p1 =   1.57004035 -> excess demand of good 1 ->     0.04715002, x1A =   0.41022372, x2A =   0.91196449, x1B =   0.63692630, x2B =   0.01400807
#  10: p1 =   1.63263577 -> excess demand of good 1 ->     0.00700219, x1A =   0.39449570, x2A =   0.96204082, x1B =   0.61250649, x2B =   0.02652715
#  15: p1 =   1.64221792 -> excess demand of good 1 ->     0.00112645, x1A =   0.39219387, x2A =   0.96970654, x1B =   0.60893258, x2B =   0.02844358
#  20: p1 =   1.64376635 -> excess demand of good 1 ->     0.00018339, x1A =   0.39182442, x2A =   0.97094528, x1B =   0.60835897, x2B =   0.02875327
#  25: p1 =   1.64401862 -> excess demand of good 1 ->     0.00002991, x1A =   0.39176430, x2A =   0.97114710, x1B =   0.60826562, x2B =   0.02880372
#  30: p1 =   1.64405977 -> excess demand of good 1 ->     0.00000488, x1A =   0.39175449, x2A =   0.97118002, x1B =   0.60825039, x2B =   0.02881195
#  35: p1 =   1.64406649 -> excess demand of good 1 ->     0.00000080, x1A =   0.39175289, x2A =   0.97118539, x1B =   0.60824791, x2B =   0.02881330
#  40: p1 =   1.64406758 -> excess demand of good 1 ->     0.00000013, x1A =   0.39175263, x2A =   0.97118627, x1B =   0.60824750, x2B =   0.02881352
#  45: p1 =   1.64406776 -> excess demand of good 1 ->     0.00000002, x1A =   0.39175259, x2A =   0.97118641, x1B =   0.60824744, x2B =   0.02881355
#
# Solved!
#   48: p1 =   1.64406778, x1A =   0.39175258, x2A =   0.97118643
#  Excess demand of good 1:     0.00000001
#  Excess demand of good 2:    -0.00000001
#   0: p1 =   1.00000000 -> excess demand of good 1 ->     0.49375000, x1A =   0.59375000, x2A =   0.50625000, x1B =   0.90000000, x2B =   0.00000000
#   1: p1 =   1.24687500 -> excess demand of good 1 ->     0.23759398, x1A =   0.47619048, x2A =   0.70375000, x1B =   0.76140351, x2B =   0.00000000
#   2: p1 =   1.36567199 -> excess demand of good 1 ->     0.14733582, x1A =   0.43476765, x2A =   0.79878759, x1B =   0.71256817, x2B =   0.00000000
#   3: p1 =   1.43933990 -> excess demand of good 1 ->     0.09884953, x1A =   0.41251549, x2A =   0.85772192, x1B =   0.68633405, x2B =   0.00000000
#   4: p1 =   1.48876467 -> excess demand of good 1 ->     0.06900907, x1A =   0.39882059, x2A =   0.89726174, x1B =   0.67018848, x2B =   0.00000000
#   5: p1 =   1.52326920 -> excess demand of good 1 ->     0.04626943, x1A =   0.38978665, x2A =   0.92486536, x1B =   0.65648278, x2B =   0.00465384
#  10: p1 =   1.58360082 -> excess demand of good 1 ->     0.00640892, x1A =   0.37493666, x2A =   0.97313066, x1B =   0.63147227, x2B =   0.01672016
#  15: p1 =   1.59221716 -> excess demand of good 1 ->     0.00096270, x1A =   0.37290767, x2A =   0.98002373, x1B =   0.62805503, x2B =   0.01844343
#  20: p1 =   1.59351694 -> excess demand of good 1 ->     0.00014626, x1A =   0.37260351, x2A =   0.98106355, x1B =   0.62754275, x2B =   0.01870339
#  25: p1 =   1.59371453 -> excess demand of good 1 ->     0.00002226, x1A =   0.37255731, x2A =   0.98122162, x1B =   0.62746495, x2B =   0.01874291
#  30: p1 =   1.59374460 -> excess demand of good 1 ->     0.00000339, x1A =   0.37255028, x2A =   0.98124568, x1B =   0.62745311, x2B =   0.01874892
#  35: p1 =   1.59374918 -> excess demand of good 1 ->     0.00000052, x1A =   0.37254921, x2A =   0.98124934, x1B =   0.62745130, x2B =   0.01874984
#  40: p1 =   1.59374987 -> excess demand of good 1 ->     0.00000008, x1A =   0.37254905, x2A =   0.98124990, x1B =   0.62745103, x2B =   0.01874997
#  45: p1 =   1.59374998 -> excess demand of good 1 ->     0.00000001, x1A =   0.37254902, x2A =   0.98124998, x1B =   0.62745099, x2B =   0.01875000
#
# Solved!
#   46: p1 =   1.59374999, x1A =   0.37254902, x2A =   0.98124999
#  Excess demand of good 1:     0.00000001
#  Excess demand of good 2:    -0.00000001
#   0: p1 =   1.00000000 -> excess demand of good 1 ->     0.45072464, x1A =   0.55072464, x2A =   0.54927536, x1B =   0.90000000, x2B =   0.00000000
#   1: p1 =   1.22536232 -> excess demand of good 1 ->     0.22069781, x1A =   0.44943820, x2A =   0.72956522, x1B =   0.77125961, x2B =   0.00000000
#   2: p1 =   1.33571122 -> excess demand of good 1 ->     0.13637353, x1A =   0.41230816, x2A =   0.81784434, x1B =   0.72406537, x2B =   0.00000000
#   3: p1 =   1.40389799 -> excess demand of good 1 ->     0.09089424, x1A =   0.39228252, x2A =   0.87239376, x1B =   0.69861173, x2B =   0.00000000
#   4: p1 =   1.44934511 -> excess demand of good 1 ->     0.06295847, x1A =   0.37998171, x2A =   0.90875145, x1B =   0.68297676, x2B =   0.00000000
#   5: p1 =   1.48082435 -> excess demand of good 1 ->     0.04461377, x1A =   0.37190409, x2A =   0.93393484, x1B =   0.67270968, x2B =   0.00000000
#  10: p1 =   1.54105066 -> excess demand of good 1 ->     0.00627752, x1A =   0.35736959, x2A =   0.98211589, x1B =   0.64890794, x2B =   0.00821013
#  15: p1 =   1.54935394 -> excess demand of good 1 ->     0.00088469, x1A =   0.35545438, x2A =   0.98875852, x1B =   0.64543031, x2B =   0.00987079
#  20: p1 =   1.55052910 -> excess demand of good 1 ->     0.00012611, x1A =   0.35518497, x2A =   0.98969864, x1B =   0.64494114, x2B =   0.01010582
#  25: p1 =   1.55069672 -> excess demand of good 1 ->     0.00001801, x1A =   0.35514658, x2A =   0.98983274, x1B =   0.64487142, x2B =   0.01013934
#  30: p1 =   1.55072065 -> excess demand of good 1 ->     0.00000257, x1A =   0.35514110, x2A =   0.98985188, x1B =   0.64486147, x2B =   0.01014413
#  35: p1 =   1.55072407 -> excess demand of good 1 ->     0.00000037, x1A =   0.35514032, x2A =   0.98985462, x1B =   0.64486005, x2B =   0.01014481
#  40: p1 =   1.55072456 -> excess demand of good 1 ->     0.00000005, x1A =   0.35514021, x2A =   0.98985501, x1B =   0.64485985, x2B =   0.01014491
#
# Solved!
#   45: p1 =   1.55072463, x1A =   0.35514019, x2A =   0.98985506
#  Excess demand of good 1:     0.00000001
#  Excess demand of good 2:    -0.00000001
#   0: p1 =   1.00000000 -> excess demand of good 1 ->     0.41351351, x1A =   0.51351351, x2A =   0.58648649, x1B =   0.90000000, x2B =   0.00000000
#   1: p1 =   1.20675676 -> excess demand of good 1 ->     0.20559910, x1A =   0.42553191, x2A =   0.75189189, x1B =   0.78006719, x2B =   0.00000000
#   2: p1 =   1.30955631 -> excess demand of good 1 ->     0.12666005, x1A =   0.39212786, x2A =   0.83413153, x1B =   0.73453219, x2B =   0.00000000
#   3: p1 =   1.37288633 -> excess demand of good 1 ->     0.08391405, x1A =   0.37403935, x2A =   0.88479555, x1B =   0.70987469, x2B =   0.00000000
#   4: p1 =   1.41484336 -> excess demand of good 1 ->     0.05770167, x1A =   0.36294726, x2A =   0.91836117, x1B =   0.69475442, x2B =   0.00000000
#   5: p1 =   1.44369419 -> excess demand of good 1 ->     0.04056133, x1A =   0.35569410, x2A =   0.94144184, x1B =   0.68486723, x2B =   0.00000000
#  10: p1 =   1.50185980 -> excess demand of good 1 ->     0.00775952, x1A =   0.34191841, x2A =   0.98797433, x1B =   0.66584111, x2B =   0.00037196
#  15: p1 =   1.51195989 -> excess demand of good 1 ->     0.00102756, x1A =   0.33963435, x2A =   0.99605440, x1B =   0.66139321, x2B =   0.00239198
#  20: p1 =   1.51330459 -> excess demand of good 1 ->     0.00013806, x1A =   0.33933256, x2A =   0.99713016, x1B =   0.66080550, x2B =   0.00266092
#  25: p1 =   1.51348539 -> excess demand of good 1 ->     0.00001858, x1A =   0.33929202, x2A =   0.99727480, x1B =   0.66072656, x2B =   0.00269708
#  30: p1 =   1.51350973 -> excess demand of good 1 ->     0.00000250, x1A =   0.33928656, x2A =   0.99729427, x1B =   0.66071594, x2B =   0.00270195
#  35: p1 =   1.51351300 -> excess demand of good 1 ->     0.00000034, x1A =   0.33928583, x2A =   0.99729689, x1B =   0.66071451, x2B =   0.00270260
#  40: p1 =   1.51351344 -> excess demand of good 1 ->     0.00000005, x1A =   0.33928573, x2A =   0.99729724, x1B =   0.66071432, x2B =   0.00270269
#
# Solved!
#   44: p1 =   1.51351350, x1A =   0.33928572, x2A =   0.99729729
#  Excess demand of good 1:     0.00000001
#  Excess demand of good 2:    -0.00000001
#   0: p1 =   1.00000000 -> excess demand of good 1 ->     0.38101266, x1A =   0.48101266, x2A =   0.61898734, x1B =   0.90000000, x2B =   0.00000000
#   1: p1 =   1.19050633 -> excess demand of good 1 ->     0.19202552, x1A =   0.40404040, x2A =   0.77139241, x1B =   0.78798511, x2B =   0.00000000
#   2: p1 =   1.28651909 -> excess demand of good 1 ->     0.11799078, x1A =   0.37388692, x2A =   0.84820261, x1B =   0.74410386, x2B =   0.00000000
#   3: p1 =   1.34551448 -> excess demand of good 1 ->     0.07774058, x1A =   0.35749348, x2A =   0.89539892, x1B =   0.72024710, x2B =   0.00000000
#   4: p1 =   1.38438477 -> excess demand of good 1 ->     0.05309568, x1A =   0.34745590, x2A =   0.92649516, x1B =   0.70563977, x2B =   0.00000000
#   5: p1 =   1.41093261 -> excess demand of good 1 ->     0.03704399, x1A =   0.34091824, x2A =   0.94773343, x1B =   0.69612575, x2B =   0.00000000
#  10: p1 =   1.46345466 -> excess demand of good 1 ->     0.00700324, x1A =   0.32868299, x2A =   0.98975107, x1B =   0.67832025, x2B =   0.00000000
#  15: p1 =   1.47365219 -> excess demand of good 1 ->     0.00141886, x1A =   0.32640854, x2A =   0.99790910, x1B =   0.67501032, x2B =   0.00000000
#  20: p1 =   1.47572857 -> excess demand of good 1 ->     0.00029125, x1A =   0.32594928, x2A =   0.99957020, x1B =   0.67434197, x2B =   0.00000000
#  25: p1 =   1.47615522 -> excess demand of good 1 ->     0.00005994, x1A =   0.32585507, x2A =   0.99991151, x1B =   0.67420488, x2B =   0.00000000
#  30: p1 =   1.47624304 -> excess demand of good 1 ->     0.00001234, x1A =   0.32583568, x2A =   0.99998178, x1B =   0.67417666, x2B =   0.00000000
#  35: p1 =   1.47626113 -> excess demand of good 1 ->     0.00000254, x1A =   0.32583169, x2A =   0.99999625, x1B =   0.67417085, x2B =   0.00000000
#  40: p1 =   1.47626486 -> excess demand of good 1 ->     0.00000052, x1A =   0.32583087, x2A =   0.99999923, x1B =   0.67416966, x2B =   0.00000000
#  45: p1 =   1.47626562 -> excess demand of good 1 ->     0.00000011, x1A =   0.32583070, x2A =   0.99999984, x1B =   0.67416941, x2B =   0.00000000
#  50: p1 =   1.47626578 -> excess demand of good 1 ->     0.00000002, x1A =   0.32583066, x2A =   0.99999997, x1B =   0.67416936, x2B =   0.00000000
#
# Solved!
#   53: p1 =   1.47626581, x1A =   0.32583066, x2A =   0.99999999
#  Excess demand of good 1:     0.00000001
#  Excess demand of good 2:    -0.00000001
#   0: p1 =   1.00000000 -> excess demand of good 1 ->     0.35238095, x1A =   0.45238095, x2A =   0.64761905, x1B =   0.90000000, x2B =   0.00000000
#   1: p1 =   1.17619048 -> excess demand of good 1 ->     0.17975709, x1A =   0.38461538, x2A =   0.78857143, x1B =   0.79514170, x2B =   0.00000000
#   2: p1 =   1.26606902 -> excess demand of good 1 ->     0.11020390, x1A =   0.35731145, x2A =   0.86047426, x1B =   0.75289245, x2B =   0.00000000
#   3: p1 =   1.32117097 -> excess demand of good 1 ->     0.07224211, x1A =   0.34240909, x2A =   0.90455582, x1B =   0.72983302, x2B =   0.00000000
#   4: p1 =   1.35729202 -> excess demand of good 1 ->     0.04902949, x1A =   0.33329670, x2A =   0.93345266, x1B =   0.71573279, x2B =   0.00000000
#   5: p1 =   1.38180677 -> excess demand of good 1 ->     0.03396679, x1A =   0.32738366, x2A =   0.95306446, x1B =   0.70658313, x2B =   0.00000000
#  10: p1 =   1.42945980 -> excess demand of good 1 ->     0.00616534, x1A =   0.31646987, x2A =   0.99118689, x1B =   0.68969548, x2B =   0.00000000
#  15: p1 =   1.43832854 -> excess demand of good 1 ->     0.00119453, x1A =   0.31451851, x2A =   0.99828188, x1B =   0.68667601, x2B =   0.00000000
#  20: p1 =   1.44005462 -> excess demand of good 1 ->     0.00023420, x1A =   0.31414152, x2A =   0.99966274, x1B =   0.68609267, x2B =   0.00000000
#  25: p1 =   1.44039333 -> excess demand of good 1 ->     0.00004602, x1A =   0.31406765, x2A =   0.99993371, x1B =   0.68597837, x2B =   0.00000000
#  30: p1 =   1.44045990 -> excess demand of good 1 ->     0.00000905, x1A =   0.31405314, x2A =   0.99998697, x1B =   0.68595591, x2B =   0.00000000
#  35: p1 =   1.44047299 -> excess demand of good 1 ->     0.00000178, x1A =   0.31405029, x2A =   0.99999744, x1B =   0.68595149, x2B =   0.00000000
#  40: p1 =   1.44047556 -> excess demand of good 1 ->     0.00000035, x1A =   0.31404972, x2A =   0.99999950, x1B =   0.68595063, x2B =   0.00000000
#  45: p1 =   1.44047607 -> excess demand of good 1 ->     0.00000007, x1A =   0.31404961, x2A =   0.99999990, x1B =   0.68595045, x2B =   0.00000000
#  50: p1 =   1.44047617 -> excess demand of good 1 ->     0.00000001, x1A =   0.31404959, x2A =   0.99999998, x1B =   0.68595042, x2B =   0.00000000
#
# Solved!
#   51: p1 =   1.44047617, x1A =   0.31404959, x2A =   0.99999999
#  Excess demand of good 1:     0.00000001
#  Excess demand of good 2:    -0.00000001
#   0: p1 =   1.00000000 -> excess demand of good 1 ->     0.32696629, x1A =   0.42696629, x2A =   0.67303371, x1B =   0.90000000, x2B =   0.00000000
#   1: p1 =   1.16348315 -> excess demand of good 1 ->     0.16861420, x1A =   0.36697248, x2A =   0.80382022, x1B =   0.80164172, x2B =   0.00000000
#   2: p1 =   1.24779024 -> excess demand of good 1 ->     0.10316966, x1A =   0.34217794, x2A =   0.87126590, x1B =   0.76099172, x2B =   0.00000000
#   3: p1 =   1.29937507 -> excess demand of good 1 ->     0.06731408, x1A =   0.32859357, x2A =   0.91253377, x1B =   0.73872051, x2B =   0.00000000
#   4: p1 =   1.33303211 -> excess demand of good 1 ->     0.04541571, x1A =   0.32029708, x2A =   0.93945940, x1B =   0.72511863, x2B =   0.00000000
#   5: p1 =   1.35573997 -> excess demand of good 1 ->     0.03125549, x1A =   0.31493229, x2A =   0.95762568, x1B =   0.71632320, x2B =   0.00000000
#  10: p1 =   1.39915924 -> excess demand of good 1 ->     0.00545964, x1A =   0.30515918, x2A =   0.99236110, x1B =   0.70030045, x2B =   0.00000000
#  15: p1 =   1.40692418 -> excess demand of good 1 ->     0.00101423, x1A =   0.30347498, x2A =   0.99857306, x1B =   0.69753925, x2B =   0.00000000
#  20: p1 =   1.40837258 -> excess demand of good 1 ->     0.00019045, x1A =   0.30316288, x2A =   0.99973177, x1B =   0.69702757, x2B =   0.00000000
#  25: p1 =   1.40864477 -> excess demand of good 1 ->     0.00003584, x1A =   0.30310430, x2A =   0.99994952, x1B =   0.69693153, x2B =   0.00000000
#  30: p1 =   1.40869599 -> excess demand of good 1 ->     0.00000675, x1A =   0.30309328, x2A =   0.99999050, x1B =   0.69691346, x2B =   0.00000000
#  35: p1 =   1.40870563 -> excess demand of good 1 ->     0.00000127, x1A =   0.30309121, x2A =   0.99999821, x1B =   0.69691006, x2B =   0.00000000
#  40: p1 =   1.40870744 -> excess demand of good 1 ->     0.00000024, x1A =   0.30309082, x2A =   0.99999966, x1B =   0.69690942, x2B =   0.00000000
#  45: p1 =   1.40870779 -> excess demand of good 1 ->     0.00000004, x1A =   0.30309074, x2A =   0.99999994, x1B =   0.69690930, x2B =   0.00000000
#
# Solved!
#   50: p1 =   1.40870785, x1A =   0.30309073, x2A =   0.99999999
#  Excess demand of good 1:     0.00000001
#  Excess demand of good 2:    -0.00000001
#   0: p1 =   1.00000000 -> excess demand of good 1 ->     0.30425532, x1A =   0.40425532, x2A =   0.69574468, x1B =   0.90000000, x2B =   0.00000000
#   1: p1 =   1.15212766 -> excess demand of good 1 ->     0.15844875, x1A =   0.35087719, x2A =   0.81744681, x1B =   0.80757156, x2B =   0.00000000
#   2: p1 =   1.23135204 -> excess demand of good 1 ->     0.09678279, x1A =   0.32830199, x2A =   0.88082631, x1B =   0.76848081, x2B =   0.00000000
#   3: p1 =   1.27974343 -> excess demand of good 1 ->     0.06287242, x1A =   0.31588779, x2A =   0.91953943, x1B =   0.74698464, x2B =   0.00000000
#   4: p1 =   1.31117965 -> excess demand of good 1 ->     0.04218461, x1A =   0.30831421, x2A =   0.94468840, x1B =   0.73387040, x2B =   0.00000000
#   5: p1 =   1.33227195 -> excess demand of good 1 ->     0.02885129, x1A =   0.30343303, x2A =   0.96156224, x1B =   0.72541825, x2B =   0.00000000
#  10: p1 =   1.37198376 -> excess demand of good 1 ->     0.00486034, x1A =   0.29465022, x2A =   0.99333169, x1B =   0.71021012, x2B =   0.00000000
#  15: p1 =   1.37882349 -> excess demand of good 1 ->     0.00086779, x1A =   0.29318859, x2A =   0.99880347, x1B =   0.70767920, x2B =   0.00000000
#  20: p1 =   1.38004923 -> excess demand of good 1 ->     0.00015647, x1A =   0.29292819, x2A =   0.99978407, x1B =   0.70722828, x2B =   0.00000000
#  30: p1 =   1.29166359 -> excess demand of good 1 ->     0.00000191, x1A =   0.25806513, x2A =   0.99999754, x1B =   0.74193678, x2B =   0.00000000
#  35: p1 =   1.29166618 -> excess demand of good 1 ->     0.00000030, x1A =   0.25806461, x2A =   0.99999961, x1B =   0.74193569, x2B =   0.00000000
#  40: p1 =   1.29166659 -> excess demand of good 1 ->     0.00000005, x1A =   0.25806453, x2A =   0.99999994, x1B =   0.74193552, x2B =   0.00000000
#
# Solved!
#   45: p1 =   1.29166665, x1A =   0.25806452, x2A =   0.99999999
#  Excess demand of good 1:     0.00000001
#  Excess demand of good 2:    -0.00000001

# %% [markdown]
# **Question C:** Find the equilibrium when $\alpha = 0.1$.

# %%
model_ = ExchangeEconomyModelQuasiLinearClass()
model_.par.alpha = 0.1

try:
    model_.solve_walras(p_guess=1.0,print_output=False)
except:
    print(f'No convergence for alpha = {model_.par.alpha:.2f}')

# Increase maxiter and lower tol, try again
model_.par.maxiter = 1000
model_.par.tol = 1e-6

print('Trying again...')
model_.solve_walras(p_guess=1.0,print_output=True)
# Out:
# No convergence for alpha = 0.10
# Trying again...
#   0: p1 =   1.00000000 -> excess demand of good 1 ->     1.00000000, x1A =   1.10000000, x2A =   0.00000000, x1B =   0.90000000, x2B =   0.00000000
#   1: p1 =   1.50000000 -> excess demand of good 1 ->     0.66666667, x1A =   1.00000000, x2A =   0.00000000, x1B =   0.66666667, x2B =   0.00000000
#   2: p1 =   1.83333333 -> excess demand of good 1 ->     0.50909091, x1A =   0.96363636, x2A =   0.00000000, x1B =   0.54545455, x2B =   0.06666667
#   3: p1 =   2.08787879 -> excess demand of good 1 ->     0.42264151, x1A =   0.94368650, x2A =   0.00000000, x1B =   0.47895501, x2B =   0.11757576
#   4: p1 =   2.29919954 -> excess demand of good 1 ->     0.36541417, x1A =   0.93048019, x2A =   0.00000000, x1B =   0.43493398, x2B =   0.15983991
#   5: p1 =   2.48190663 -> excess demand of good 1 ->     0.32379086, x1A =   0.92087481, x2A =   0.00000000, x1B =   0.40291604, x2B =   0.19638133
#  10: p1 =   3.15852354 -> excess demand of good 1 ->     0.21158471, x1A =   0.89498109, x2A =   0.00000000, x1B =   0.31660362, x2B =   0.33170471
#  15: p1 =   3.62810494 -> excess demand of good 1 ->     0.15831378, x1A =   0.88268780, x2A =   0.00000000, x1B =   0.27562599, x2B =   0.42562099
#  20: p1 =   3.98875671 -> excess demand of good 1 ->     0.12591609, x1A =   0.87521141, x2A =   0.00000000, x1B =   0.25070469, x2B =   0.49775134
#  25: p1 =   4.27988362 -> excess demand of good 1 ->     0.10374658, x1A =   0.87009536, x2A =   0.00000000, x1B =   0.23365121, x2B =   0.55597672
#  30: p1 =   4.52206441 -> excess demand of good 1 ->     0.08747932, x1A =   0.86634138, x2A =   0.00000000, x1B =   0.22113794, x2B =   0.60441288
#  35: p1 =   4.72765047 -> excess demand of good 1 ->     0.07497803, x1A =   0.86345647, x2A =   0.00000000, x1B =   0.21152156, x2B =   0.64553009
#  40: p1 =   4.90473744 -> excess demand of good 1 ->     0.06504987, x1A =   0.86116535, x2A =   0.00000000, x1B =   0.20388451, x2B =   0.68094749
#  45: p1 =   5.05896611 -> excess demand of good 1 ->     0.05696950, x1A =   0.85930065, x2A =   0.00000000, x1B =   0.19766885, x2B =   0.71179322
#  50: p1 =   5.19444814 -> excess demand of good 1 ->     0.05026720, x1A =   0.85775397, x2A =   0.00000000, x1B =   0.19251323, x2B =   0.73888963
#  55: p1 =   5.31428611 -> excess demand of good 1 ->     0.04462364, x1A =   0.85645161, x2A =   0.00000000, x1B =   0.18817203, x2B =   0.76285722
#  60: p1 =   5.42088639 -> excess demand of good 1 ->     0.03981318, x1A =   0.85534150, x2A =   0.00000000, x1B =   0.18447168, x2B =   0.78417728
#  65: p1 =   5.51615732 -> excess demand of good 1 ->     0.03567131, x1A =   0.85438569, x2A =   0.00000000, x1B =   0.18128562, x2B =   0.80323146
#  70: p1 =   5.60164038 -> excess demand of good 1 ->     0.03207488, x1A =   0.85355574, x2A =   0.00000000, x1B =   0.17851914, x2B =   0.82032808
#  75: p1 =   5.67860011 -> excess demand of good 1 ->     0.02892966, x1A =   0.85282992, x2A =   0.00000000, x1B =   0.17609974, x2B =   0.83572002
#  80: p1 =   5.74808753 -> excess demand of good 1 ->     0.02616218, x1A =   0.85219127, x2A =   0.00000000, x1B =   0.17397091, x2B =   0.84961751
#  85: p1 =   5.81098613 -> excess demand of good 1 ->     0.02371418, x1A =   0.85162635, x2A =   0.00000000, x1B =   0.17208783, x2B =   0.86219723
#  90: p1 =   5.86804580 -> excess demand of good 1 ->     0.02153883, x1A =   0.85112435, x2A =   0.00000000, x1B =   0.17041448, x2B =   0.87360916
#  95: p1 =   5.91990849 -> excess demand of good 1 ->     0.01959799, x1A =   0.85067646, x2A =   0.00000000, x1B =   0.16892153, x2B =   0.88398170
# 100: p1 =   5.96712789 -> excess demand of good 1 ->     0.01786025, x1A =   0.85027544, x2A =   0.00000000, x1B =   0.16758481, x2B =   0.89342558
# 105: p1 =   6.01018471 -> excess demand of good 1 ->     0.01629951, x1A =   0.84991527, x2A =   0.00000000, x1B =   0.16638424, x2B =   0.90203694
# 110: p1 =   6.04949876 -> excess demand of good 1 ->     0.01489384, x1A =   0.84959089, x2A =   0.00000000, x1B =   0.16530295, x2B =   0.90989975
# 115: p1 =   6.08543858 -> excess demand of good 1 ->     0.01362470, x1A =   0.84929801, x2A =   0.00000000, x1B =   0.16432669, x2B =   0.91708772
# 120: p1 =   6.11832922 -> excess demand of good 1 ->     0.01247631, x1A =   0.84903299, x2A =   0.00000000, x1B =   0.16344331, x2B =   0.92366584
# 125: p1 =   6.14845858 -> excess demand of good 1 ->     0.01143511, x1A =   0.84879272, x2A =   0.00000000, x1B =   0.16264239, x2B =   0.92969172
# 130: p1 =   6.17608262 -> excess demand of good 1 ->     0.01048941, x1A =   0.84857448, x2A =   0.00000000, x1B =   0.16191493, x2B =   0.93521652
# 135: p1 =   6.20142967 -> excess demand of good 1 ->     0.00962908, x1A =   0.84837594, x2A =   0.00000000, x1B =   0.16125314, x2B =   0.94028593
# 140: p1 =   6.22470407 -> excess demand of good 1 ->     0.00884527, x1A =   0.84819506, x2A =   0.00000000, x1B =   0.16065021, x2B =   0.94494081
# 145: p1 =   6.24608917 -> excess demand of good 1 ->     0.00813023, x1A =   0.84803005, x2A =   0.00000000, x1B =   0.16010018, x2B =   0.94921783
# 150: p1 =   6.26574992 -> excess demand of good 1 ->     0.00747716, x1A =   0.84787934, x2A =   0.00000000, x1B =   0.15959782, x2B =   0.95314998
# 155: p1 =   6.28383506 -> excess demand of good 1 ->     0.00688003, x1A =   0.84774155, x2A =   0.00000000, x1B =   0.15913849, x2B =   0.95676701
# 160: p1 =   6.30047899 -> excess demand of good 1 ->     0.00633352, x1A =   0.84761543, x2A =   0.00000000, x1B =   0.15871809, x2B =   0.96009580
# 165: p1 =   6.31580342 -> excess demand of good 1 ->     0.00583288, x1A =   0.84749990, x2A =   0.00000000, x1B =   0.15833298, x2B =   0.96316068
# 170: p1 =   6.32991869 -> excess demand of good 1 ->     0.00537389, x1A =   0.84739397, x2A =   0.00000000, x1B =   0.15797991, x2B =   0.96598374
# 175: p1 =   6.34292505 -> excess demand of good 1 ->     0.00495276, x1A =   0.84729679, x2A =   0.00000000, x1B =   0.15765597, x2B =   0.96858501
# 180: p1 =   6.35491373 -> excess demand of good 1 ->     0.00456611, x1A =   0.84720756, x2A =   0.00000000, x1B =   0.15735855, x2B =   0.97098275
# 185: p1 =   6.36596779 -> excess demand of good 1 ->     0.00421090, x1A =   0.84712559, x2A =   0.00000000, x1B =   0.15708531, x2B =   0.97319356
# 190: p1 =   6.37616303 -> excess demand of good 1 ->     0.00388437, x1A =   0.84705024, x2A =   0.00000000, x1B =   0.15683413, x2B =   0.97523261
# 195: p1 =   6.38556864 -> excess demand of good 1 ->     0.00358406, x1A =   0.84698094, x2A =   0.00000000, x1B =   0.15660312, x2B =   0.97711373
# 200: p1 =   6.39424788 -> excess demand of good 1 ->     0.00330773, x1A =   0.84691717, x2A =   0.00000000, x1B =   0.15639056, x2B =   0.97884958
# 205: p1 =   6.40225861 -> excess demand of good 1 ->     0.00305334, x1A =   0.84685846, x2A =   0.00000000, x1B =   0.15619488, x2B =   0.98045172
# 210: p1 =   6.40965384 -> excess demand of good 1 ->     0.00281907, x1A =   0.84680440, x2A =   0.00000000, x1B =   0.15601467, x2B =   0.98193077
# 215: p1 =   6.41648213 -> excess demand of good 1 ->     0.00260323, x1A =   0.84675459, x2A =   0.00000000, x1B =   0.15584864, x2B =   0.98329643
# 220: p1 =   6.42278805 -> excess demand of good 1 ->     0.00240431, x1A =   0.84670869, x2A =   0.00000000, x1B =   0.15569563, x2B =   0.98455761
# 225: p1 =   6.42861247 -> excess demand of good 1 ->     0.00222093, x1A =   0.84666637, x2A =   0.00000000, x1B =   0.15555456, x2B =   0.98572249
# 230: p1 =   6.43399296 -> excess demand of good 1 ->     0.00205182, x1A =   0.84662734, x2A =   0.00000000, x1B =   0.15542448, x2B =   0.98679859
# 235: p1 =   6.43896401 -> excess demand of good 1 ->     0.00189583, x1A =   0.84659135, x2A =   0.00000000, x1B =   0.15530449, x2B =   0.98779280
# 240: p1 =   6.44355735 -> excess demand of good 1 ->     0.00175191, x1A =   0.84655813, x2A =   0.00000000, x1B =   0.15519378, x2B =   0.98871147
# 245: p1 =   6.44780217 -> excess demand of good 1 ->     0.00161909, x1A =   0.84652748, x2A =   0.00000000, x1B =   0.15509161, x2B =   0.98956043
# 250: p1 =   6.45172534 -> excess demand of good 1 ->     0.00149649, x1A =   0.84649919, x2A =   0.00000000, x1B =   0.15499730, x2B =   0.99034507
# 255: p1 =   6.45535156 -> excess demand of good 1 ->     0.00138330, x1A =   0.84647307, x2A =   0.00000000, x1B =   0.15491023, x2B =   0.99107031
# 260: p1 =   6.45870363 -> excess demand of good 1 ->     0.00127878, x1A =   0.84644895, x2A =   0.00000000, x1B =   0.15482983, x2B =   0.99174073
# 265: p1 =   6.46180252 -> excess demand of good 1 ->     0.00118225, x1A =   0.84642667, x2A =   0.00000000, x1B =   0.15475558, x2B =   0.99236050
# 270: p1 =   6.46466759 -> excess demand of good 1 ->     0.00109309, x1A =   0.84640610, x2A =   0.00000000, x1B =   0.15468699, x2B =   0.99293352
# 275: p1 =   6.46731664 -> excess demand of good 1 ->     0.00101072, x1A =   0.84638709, x2A =   0.00000000, x1B =   0.15462363, x2B =   0.99346333
# 280: p1 =   6.46976615 -> excess demand of good 1 ->     0.00093462, x1A =   0.84636953, x2A =   0.00000000, x1B =   0.15456509, x2B =   0.99395323
# 285: p1 =   6.47203126 -> excess demand of good 1 ->     0.00086430, x1A =   0.84635330, x2A =   0.00000000, x1B =   0.15451100, x2B =   0.99440625
# 290: p1 =   6.47412599 -> excess demand of good 1 ->     0.00079931, x1A =   0.84633830, x2A =   0.00000000, x1B =   0.15446100, x2B =   0.99482520
# 295: p1 =   6.47606324 -> excess demand of good 1 ->     0.00073924, x1A =   0.84632444, x2A =   0.00000000, x1B =   0.15441480, x2B =   0.99521265
# 300: p1 =   6.47785494 -> excess demand of good 1 ->     0.00068372, x1A =   0.84631163, x2A =   0.00000000, x1B =   0.15437209, x2B =   0.99557099
# 305: p1 =   6.47951209 -> excess demand of good 1 ->     0.00063239, x1A =   0.84629978, x2A =   0.00000000, x1B =   0.15433261, x2B =   0.99590242
# 310: p1 =   6.48104488 -> excess demand of good 1 ->     0.00058494, x1A =   0.84628883, x2A =   0.00000000, x1B =   0.15429611, x2B =   0.99620898
# 315: p1 =   6.48246267 -> excess demand of good 1 ->     0.00054107, x1A =   0.84627871, x2A =   0.00000000, x1B =   0.15426236, x2B =   0.99649253
# 320: p1 =   6.48377414 -> excess demand of good 1 ->     0.00050051, x1A =   0.84626935, x2A =   0.00000000, x1B =   0.15423116, x2B =   0.99675483
# 325: p1 =   6.48498732 -> excess demand of good 1 ->     0.00046300, x1A =   0.84626069, x2A =   0.00000000, x1B =   0.15420231, x2B =   0.99699746
# 330: p1 =   6.48610958 -> excess demand of good 1 ->     0.00042831, x1A =   0.84625269, x2A =   0.00000000, x1B =   0.15417563, x2B =   0.99722192
# 335: p1 =   6.48714779 -> excess demand of good 1 ->     0.00039624, x1A =   0.84624529, x2A =   0.00000000, x1B =   0.15415095, x2B =   0.99742956
# 340: p1 =   6.48810825 -> excess demand of good 1 ->     0.00036657, x1A =   0.84623844, x2A =   0.00000000, x1B =   0.15412813, x2B =   0.99762165
# 345: p1 =   6.48899681 -> excess demand of good 1 ->     0.00033913, x1A =   0.84623211, x2A =   0.00000000, x1B =   0.15410703, x2B =   0.99779936
# 350: p1 =   6.48981887 -> excess demand of good 1 ->     0.00031376, x1A =   0.84622625, x2A =   0.00000000, x1B =   0.15408751, x2B =   0.99796377
# 355: p1 =   6.49057943 -> excess demand of good 1 ->     0.00029028, x1A =   0.84622083, x2A =   0.00000000, x1B =   0.15406945, x2B =   0.99811589
# 360: p1 =   6.49128309 -> excess demand of good 1 ->     0.00026857, x1A =   0.84621582, x2A =   0.00000000, x1B =   0.15405275, x2B =   0.99825662
# 365: p1 =   6.49193412 -> excess demand of good 1 ->     0.00024849, x1A =   0.84621119, x2A =   0.00000000, x1B =   0.15403730, x2B =   0.99838682
# 370: p1 =   6.49253648 -> excess demand of good 1 ->     0.00022991, x1A =   0.84620690, x2A =   0.00000000, x1B =   0.15402301, x2B =   0.99850730
# 375: p1 =   6.49309380 -> excess demand of good 1 ->     0.00021272, x1A =   0.84620294, x2A =   0.00000000, x1B =   0.15400979, x2B =   0.99861876
# 380: p1 =   6.49360946 -> excess demand of good 1 ->     0.00019683, x1A =   0.84619927, x2A =   0.00000000, x1B =   0.15399756, x2B =   0.99872189
# 385: p1 =   6.49408659 -> excess demand of good 1 ->     0.00018212, x1A =   0.84619587, x2A =   0.00000000, x1B =   0.15398624, x2B =   0.99881732
# 390: p1 =   6.49452806 -> excess demand of good 1 ->     0.00016851, x1A =   0.84619273, x2A =   0.00000000, x1B =   0.15397578, x2B =   0.99890561
# 395: p1 =   6.49493655 -> excess demand of good 1 ->     0.00015592, x1A =   0.84618983, x2A =   0.00000000, x1B =   0.15396609, x2B =   0.99898731
# 400: p1 =   6.49531452 -> excess demand of good 1 ->     0.00014427, x1A =   0.84618714, x2A =   0.00000000, x1B =   0.15395713, x2B =   0.99906290
# 405: p1 =   6.49566426 -> excess demand of good 1 ->     0.00013350, x1A =   0.84618465, x2A =   0.00000000, x1B =   0.15394884, x2B =   0.99913285
# 410: p1 =   6.49598788 -> excess demand of good 1 ->     0.00012353, x1A =   0.84618235, x2A =   0.00000000, x1B =   0.15394117, x2B =   0.99919758
# 415: p1 =   6.49628732 -> excess demand of good 1 ->     0.00011430, x1A =   0.84618022, x2A =   0.00000000, x1B =   0.15393408, x2B =   0.99925746
# 420: p1 =   6.49656441 -> excess demand of good 1 ->     0.00010577, x1A =   0.84617825, x2A =   0.00000000, x1B =   0.15392751, x2B =   0.99931288
# 425: p1 =   6.49682081 -> excess demand of good 1 ->     0.00009787, x1A =   0.84617643, x2A =   0.00000000, x1B =   0.15392144, x2B =   0.99936416
# 430: p1 =   6.49705806 -> excess demand of good 1 ->     0.00009056, x1A =   0.84617475, x2A =   0.00000000, x1B =   0.15391582, x2B =   0.99941161
# 435: p1 =   6.49727760 -> excess demand of good 1 ->     0.00008380, x1A =   0.84617318, x2A =   0.00000000, x1B =   0.15391062, x2B =   0.99945552
# 440: p1 =   6.49748075 -> excess demand of good 1 ->     0.00007755, x1A =   0.84617174, x2A =   0.00000000, x1B =   0.15390580, x2B =   0.99949615
# 445: p1 =   6.49766873 -> excess demand of good 1 ->     0.00007176, x1A =   0.84617041, x2A =   0.00000000, x1B =   0.15390135, x2B =   0.99953375
# 450: p1 =   6.49784269 -> excess demand of good 1 ->     0.00006640, x1A =   0.84616917, x2A =   0.00000000, x1B =   0.15389723, x2B =   0.99956854
# 455: p1 =   6.49800366 -> excess demand of good 1 ->     0.00006144, x1A =   0.84616803, x2A =   0.00000000, x1B =   0.15389342, x2B =   0.99960073
# 460: p1 =   6.49815261 -> excess demand of good 1 ->     0.00005686, x1A =   0.84616697, x2A =   0.00000000, x1B =   0.15388989, x2B =   0.99963052
# 465: p1 =   6.49829045 -> excess demand of good 1 ->     0.00005262, x1A =   0.84616599, x2A =   0.00000000, x1B =   0.15388663, x2B =   0.99965809
# 470: p1 =   6.49841800 -> excess demand of good 1 ->     0.00004869, x1A =   0.84616508, x2A =   0.00000000, x1B =   0.15388361, x2B =   0.99968360
# 475: p1 =   6.49853603 -> excess demand of good 1 ->     0.00004506, x1A =   0.84616424, x2A =   0.00000000, x1B =   0.15388081, x2B =   0.99970721
# 480: p1 =   6.49864526 -> excess demand of good 1 ->     0.00004169, x1A =   0.84616347, x2A =   0.00000000, x1B =   0.15387823, x2B =   0.99972905
# 485: p1 =   6.49874633 -> excess demand of good 1 ->     0.00003858, x1A =   0.84616275, x2A =   0.00000000, x1B =   0.15387583, x2B =   0.99974927
# 490: p1 =   6.49883986 -> excess demand of good 1 ->     0.00003570, x1A =   0.84616209, x2A =   0.00000000, x1B =   0.15387362, x2B =   0.99976797
# 495: p1 =   6.49892641 -> excess demand of good 1 ->     0.00003304, x1A =   0.84616147, x2A =   0.00000000, x1B =   0.15387157, x2B =   0.99978528
# 500: p1 =   6.49900651 -> excess demand of good 1 ->     0.00003057, x1A =   0.84616090, x2A =   0.00000000, x1B =   0.15386967, x2B =   0.99980130
# 505: p1 =   6.49908062 -> excess demand of good 1 ->     0.00002829, x1A =   0.84616038, x2A =   0.00000000, x1B =   0.15386792, x2B =   0.99981612
# 510: p1 =   6.49914921 -> excess demand of good 1 ->     0.00002618, x1A =   0.84615989, x2A =   0.00000000, x1B =   0.15386629, x2B =   0.99982984
# 515: p1 =   6.49921268 -> excess demand of good 1 ->     0.00002423, x1A =   0.84615944, x2A =   0.00000000, x1B =   0.15386479, x2B =   0.99984254
# 520: p1 =   6.49927142 -> excess demand of good 1 ->     0.00002242, x1A =   0.84615902, x2A =   0.00000000, x1B =   0.15386340, x2B =   0.99985428
# 715: p1 =   6.49996457 -> excess demand of good 1 ->     0.00000109, x1A =   0.84615410, x2A =   0.00000000, x1B =   0.15384699, x2B =   0.99999291
# 720: p1 =   6.49996721 -> excess demand of good 1 ->     0.00000101, x1A =   0.84615408, x2A =   0.00000000, x1B =   0.15384693, x2B =   0.99999344
#
# Solved!
#  721: p1 =   6.49996771, x1A =   0.84615408, x2A =   0.00000000
#  Excess demand of good 1:     0.00000099
#  Excess demand of good 2:    -0.00000646

# %% [markdown]
# ### 2.3. <a id='toc2_3_'></a>[Dictators](#toc0_)

# %% [markdown]
# When A is dictator, A maximizes own utility:
#
# $$
# \max_{(x_{1}^{A},x_{2}^{A})\in[0,1]\times[0,1]}u^{A}(x_{1}^{A},x_{2}^{A})
# $$
#
# subject to B utility not being worse than with her endowment,
#
# $$
# u^{B}(1-x_{1}^{A},1-x_{2}^{A})\geq u^{B}(\omega_{1}^{B},\omega_{2}^{B})
# $$

# %% [markdown]
# **Question A:** Solve the dictator problem for A and plot the solution together with the endowment, the improvement set, and the equilibrium.

# %%
# Solve dictator A
model_.solve_dictator_A()

par = model_.par
sol = model_.sol

fig, ax_A, ax_B = model_.create_edgeworthbox()

# Dictator allocation for A
x1A, x2A = sol.xA_dictatorA

# Allocation for B
x1B = 1 - x1A
x2B = 1 - x2A

# Plot indifference curves through dictator allocation
model_.indifference_curve_A(ax_A, x1A, x2A, color=colors[0], label='A')
model_.indifference_curve_B(ax_B, x1B, x2B, color=colors[1], label='B')

# Mark dictator allocation
ax_A.scatter(x1A, x2A, color='red', marker='o', s=60, label='dictator A')

model_.add_legend(ax_A, ax_B)
# Out:
# Dictator solution for A:
# x1A =   0.85183639
# x2A =   0.00000000
# Utility A =  -0.16036080
# Utility B =  -0.90943818

# %% [markdown]
# **Question B:** Solve the dictator problem for B and plot the solution the endowment, the improvement set, the equilibrium and the outcome when A is dictator.

# %%
# Solve for dictator B
model_.solve_dictator_B()

par = model_.par
sol = model_.sol

fig, ax_A, ax_B = model_.create_edgeworthbox()

# A's allocation chosen by dictator B
x1A, x2A = sol.xA_dictatorB

# B gets the rest
x1B = 1 - x1A
x2B = 1 - x2A

# Indifference curves THROUGH the dictator-B allocation
model_.indifference_curve_A(ax_A, x1A, x2A, color=colors[0], label='A')
model_.indifference_curve_B(ax_B, x1B, x2B, color=colors[1], label='B')


# Mark dictator-B point
ax_A.scatter(x1A, x2A, color='red', marker='o', s=60, label='dictator B')

model_.add_legend(ax_A, ax_B)
# Out:
# Dictator solution for B:
# x1A =   0.82436358, x2A =   0.00000000
# x1B =   0.17563642, x2B =   1.00000000
# Utility A =  -0.19314361
# Utility B =  -0.73933920

# %% [markdown]
# ## 3. <a id='toc3_'></a>[Production Economy with CO2 tax](#toc0_)

# %% [markdown]
# Consider a production economy with **two firms** indexed by $j \in \{1,2\}$.
#
# Each produce its own good, and maximize profits:
#
# $$
# \begin{align*}
# \max_{y_{j}}\pi_{j}&=p_{j}y_{j}-w_{j}\ell_{j}\\\text{s.t.}\;&y_{j}=A\ell_{j}^{\gamma}.
# \end{align*}
# $$
#
# **Firm 1 is green = no emissions. Firm is black = emissions proportional to output.**

# %% [markdown]
# **Optimal firm behavior** is
#
# $$
# \begin{align*}
# \ell_{j}^{\star}(w,p_{j})&=\left(\frac{p_{j}A\gamma}{w}\right)^{\frac{1}{1-\gamma}} \\
# y_{j}^{\star}(w,p_{j})&=A\left(\ell_{j}^{\star}(w,p_{j})\right)^{\gamma}
# \end{align*}
# $$

# %% [markdown]
# The **implied profits** are
#
# $$
# \pi_{j}^*(w,p_{j})=\frac{1-\gamma}{\gamma}w\left(\frac{p_{j}A\gamma}{w}\right)^{\frac{1}{1-\gamma}}
# $$

# %% [markdown]
# A single **consumer** supplies labor, and consumes the goods the firms produce. She also recieves the implied profits of the firm. She maximizes utility:
#
# $$
# \begin{align*}
# U(p_1,p_2,w,\tau,T) = \max_{c_{1},c_{2},\ell} & \log(c_{1}^{\alpha}c_{2}^{1-\alpha})-\nu\frac{\ell^{1+\epsilon}}{1+\epsilon} \\
# \text{s.t.}\,\,\,&p_{1}c_{1}+(p_{2}+\tau)c_{2}=w\ell+T+\pi_{1}^*(w,p_{1})+\pi_{2}^*(w,p_{2})
# \end{align*}
# $$
#
# where $\tau$ is a tax on good 2 and $T$ is a lump-sum transfer.

# %% [markdown]
# For a given $\ell$, it can be shown that optimal consumption behavior is
#
# $$
# \begin{align*}
# c_{1}(\ell)&=\alpha\frac{w\ell+T+\pi_{1}^*(w,p_{1})+\pi_{2}^*(w,p_{2})}{p_{1}} \\
# c_{2}(\ell)&=(1-\alpha)\frac{w\ell+T+\pi_{1}^*(w,p_{1})+\pi_{2}^*(w,p_{2})}{p_{2}+\tau} \\
# \end{align*}
# $$

# %% [markdown]
# **Optimal labor supply** is:
#
# $$
# \ell^* = \underset{\ell}{\arg\max} \log(\left(c_{1}(\ell)\right)^{\alpha}\left(c_{2}(\ell)\right)^{1-\alpha})-\nu\frac{\ell^{1+\epsilon}}{1+\epsilon}
# $$

# %% [markdown]
# This implies **optimal consumption** as:
#
# $$
# \begin{align*}
# c_1^*=c_{1}(\ell^*) \\
# c_2^*=c_{2}(\ell^*)\\
# \end{align*}
# $$

# %% [markdown]
# The **government** chooses $\tau$ and balances its budget so $T=\tau c_2^*$.

# %% [markdown]
# We initially set $\tau,T=0$. But the government care about the social welfare function:
#
# $$
# SWF = U - \kappa y_2^*
# $$
#
# where $\kappa$ measures the social cost of carbon emitted by the production of $y_2$ in equilibrium.

# %% [markdown]
# **Market clearing** requires:
#
# 1. Labor market: $\ell^* = \ell_1^* + \ell_2^*$
# 1. Good market 1: $c_1^* = y_1^*$
# 1. Good market 2: $c_2^* = y_2^*$
#
# We choose $w=1$ as numeraire.

# %%
from ProductionCO2Model import ProductionCO2ModelClass

# %% [markdown]
# **Note:** The solution model class is in `A3_ProductionCO2Model.py`.

# %% [markdown]
# ### 3.1. <a id='toc3_1_'></a>[Labor supply](#toc0_)

# %% [markdown]
# **Task:** Add the numerical optimizer in the `.households` method.
#
# **Question a:** Let $p_1$ vary in `[0.5,1.0,1.5]` and vary $p_2$ in `[0.5,1.0,1.5]`. How does labor supply and consumption change?

# %%
model = ProductionCO2ModelClass()

model.sol.pi1 = 0.0
model.sol.pi2 = 0.0
p2 = 1.0
for p1 in [0.5,1.0,1.5]:
    for p2 in [0.5,1.0,1.5]:
        model.households(p1,p2)
        print(f'p1 = {p1:0.2f}, p2 = {p2:0.2f}')
        print(f'households: l = {model.sol.l:0.4f}, c1 = {model.sol.c1:0.4f}, c2 = {model.sol.c2:0.4f}')
        print()
# Out:
# p1 = 0.50, p2 = 0.50
# households: l = 1.0000, c1 = 0.6000, c2 = 1.4000
#
# p1 = 0.50, p2 = 1.00
# households: l = 1.0000, c1 = 0.6000, c2 = 0.7000
#
# p1 = 0.50, p2 = 1.50
# households: l = 1.0000, c1 = 0.6000, c2 = 0.4667
#
# p1 = 1.00, p2 = 0.50
# households: l = 1.0000, c1 = 0.3000, c2 = 1.4000
#
# p1 = 1.00, p2 = 1.00
# households: l = 1.0000, c1 = 0.3000, c2 = 0.7000
#
# p1 = 1.00, p2 = 1.50
# households: l = 1.0000, c1 = 0.3000, c2 = 0.4667
#
# p1 = 1.50, p2 = 0.50
# households: l = 1.0000, c1 = 0.2000, c2 = 1.4000
#
# p1 = 1.50, p2 = 1.00
# households: l = 1.0000, c1 = 0.2000, c2 = 0.7000
#
# p1 = 1.50, p2 = 1.50
# households: l = 1.0000, c1 = 0.2000, c2 = 0.4667

# %% [markdown]
# **Question b:** Let $p_1$ vary in `[0.5,1.0,1.5]` and vary $p_2$ in `[0.5,1.0,1.5]`. How does firm behvior, firm profit and household labor supply and consumption change?

# %%
p2 = 1.0
for p1 in [0.5,1.0,1.5]:
    for p2 in [0.5,1.0,1.5]:
        model.firms(p1,p2)
        model.households(p1,p2)
        print(f'p1 = {p1:0.2f}, p2 = {p2:0.2f}')
        print(f'firms: y1 = {model.sol.y1:0.4f}, y2 = {model.sol.y2:0.4f}, pi1 = {model.sol.pi1:0.4f}, pi2 = {model.sol.pi2:0.4f}')
        print(f'households: l = {model.sol.l:0.4f}, c1 = {model.sol.c1:0.4f}, c2 = {model.sol.c2:0.4f}')
        print()
# Out:
# p1 = 0.50, p2 = 0.50
# firms: y1 = 0.2500, y2 = 0.2500, pi1 = 0.0625, pi2 = 0.0625
# households: l = 0.9600, c1 = 0.6510, c2 = 1.5190
#
# p1 = 0.50, p2 = 1.00
# firms: y1 = 0.2500, y2 = 0.5000, pi1 = 0.0625, pi2 = 0.2500
# households: l = 0.9059, c1 = 0.7311, c2 = 0.8529
#
# p1 = 0.50, p2 = 1.50
# firms: y1 = 0.2500, y2 = 0.7500, pi1 = 0.0625, pi2 = 0.5625
# households: l = 0.8292, c1 = 0.8725, c2 = 0.6786
#
# p1 = 1.00, p2 = 0.50
# firms: y1 = 0.5000, y2 = 0.2500, pi1 = 0.2500, pi2 = 0.0625
# households: l = 0.9059, c1 = 0.3655, c2 = 1.7058
#
# p1 = 1.00, p2 = 1.00
# firms: y1 = 0.5000, y2 = 0.5000, pi1 = 0.2500, pi2 = 0.2500
# households: l = 0.8581, c1 = 0.4074, c2 = 0.9507
#
# p1 = 1.00, p2 = 1.50
# firms: y1 = 0.5000, y2 = 0.7500, pi1 = 0.2500, pi2 = 0.5625
# households: l = 0.7900, c1 = 0.4807, c2 = 0.7478
#
# p1 = 1.50, p2 = 0.50
# firms: y1 = 0.7500, y2 = 0.2500, pi1 = 0.5625, pi2 = 0.0625
# households: l = 0.8292, c1 = 0.2908, c2 = 2.0359
#
# p1 = 1.50, p2 = 1.00
# firms: y1 = 0.7500, y2 = 0.5000, pi1 = 0.5625, pi2 = 0.2500
# households: l = 0.7900, c1 = 0.3205, c2 = 1.1217
#
# p1 = 1.50, p2 = 1.50
# firms: y1 = 0.7500, y2 = 0.7500, pi1 = 0.5625, pi2 = 0.5625
# households: l = 0.7335, c1 = 0.3717, c2 = 0.8673

# %% [markdown]
# ### 3.2. <a id='toc3_2_'></a>[Grid search](#toc0_)

# %% [markdown]
# **Task:** Add the required code in the `.market_clearing` method.

# %% [markdown]
# **Question:** Check market clearing conditions for $p_1$ in `linspace(0.1,2.0,10)` and $p_2$ in `linspace(0.1,2.0,10)`, and determine where they are closest to being fulfilled.

# %%
model.solve_grid_search(do_print=True, Np=10)
# Out:
# sol.p1_approx = 0.94, sol.p2_approx = 1.58

# %% [markdown]
# ### 3.3. <a id='toc3_3_'></a>[Equilibrium prices](#toc0_)

# %% [markdown]
# **Task:** Add the required code in the `.solve` method.
#
# **Question:** Find the equilibrium prices $p_1$ and $p_2$.

# %%
check = model.solve(do_print=True)
# Out:
# sol.y1 = 0.49, sol.y2 = 0.75, sol.p1 = 0.98, sol.p2 = 1.49
# Error in market clearing for good 1:   0.00000001
# Error in market clearing for good 2:   0.00000001
# Error in market clearing for good 3:  -0.00000002

# %% [markdown]
# ### 3.4. <a id='toc3_4_'></a>[Optimal CO2 tax](#toc0_)

# %% [markdown]
# **Task:** Add the required code in the `.optimal_gov` method.
#
# **Question:** What value of $\tau$ should the government choose to maximize $SWF$?

# %%
model.optimal_gov()
# Out:
# grid search:
# tau = 0.000, sol.U = -0.5876, SWF = -0.66216
# tau = 0.031, sol.U = -0.5877, SWF = -0.66179
# tau = 0.061, sol.U = -0.5878, SWF = -0.66151
# tau = 0.092, sol.U = -0.5880, SWF = -0.66130
# tau = 0.122, sol.U = -0.5882, SWF = -0.66116
# tau = 0.153, sol.U = -0.5885, SWF = -0.66109
# tau = 0.184, sol.U = -0.5889, SWF = -0.66110
# tau = 0.214, sol.U = -0.5894, SWF = -0.66117
# tau = 0.245, sol.U = -0.5899, SWF = -0.66130
# tau = 0.276, sol.U = -0.5905, SWF = -0.66149
#
# Equilibrium with optimal tau:
# sol.y1 = 0.50, sol.y2 = 0.72, sol.p1 = 1.00, sol.p2 = 1.45
# Error in market clearing for good 1:   0.00000000
# Error in market clearing for good 2:   0.00000000
# Error in market clearing for good 3:  -0.00000000
# tau = 0.167, sol.U = -0.5887, SWF = -0.66109
